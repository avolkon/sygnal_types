# %% [markdown]
# # `notebook_2_model`
#
# **Назначение:** загрузка подготовленной модели (или переиспользование кода предобработки), **предсказание** по данным конкурса и **оформление финального решения** (форматы и требования — по регламенту соревнования).
#
# Подготовка и обучение — в `notebook_1_experience.ipynb`.

# %% [markdown]
# ## 1. Загрузка модели и согласованная предобработка

# %% [markdown]
# ## 2. Предсказание на данных конкурса

# %% [markdown]
# ## 3. Финальное задание: сохранение сабмишена / отчёт по требованиям организаторов
